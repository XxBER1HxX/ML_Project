# %% [markdown]
# # Explore Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.impute import SimpleImputer
sns.set()

# %%
main_df = pd.read_csv('data.csv')
main_df
# Out:
#        avg_monthly_hrs   department  filed_complaint  last_evaluation  \
# 0                  221  engineering              NaN         0.932868
# 1                  232      support              NaN              NaN
# 2                  184        sales              NaN         0.788830
# 3                  206        sales              NaN         0.575688
# 4                  249        sales              NaN         0.845217
# ...                ...          ...              ...              ...
# 14244              178           IT              NaN         0.735865
# 14245              257        sales              NaN         0.638604
# 14246              232      finance              1.0         0.847623
# 14247              130           IT              NaN         0.757184
# 14248              159          NaN              NaN         0.578742
#
#        n_projects  recently_promoted  salary  satisfaction    status  tenure
# ...

# %%
display(main_df.describe())
display(main_df.info())
# Out:
#        avg_monthly_hrs  filed_complaint  last_evaluation    n_projects  \
# count     14249.000000           2058.0     12717.000000  14249.000000
# mean        199.795775              1.0         0.718477      3.773809
# std          50.998714              0.0         0.173062      1.253126
# min          49.000000              1.0         0.316175      1.000000
# 25%         155.000000              1.0         0.563866      3.000000
# 50%         199.000000              1.0         0.724939      4.000000
# 75%         245.000000              1.0         0.871358      5.000000
# max         310.000000              1.0         1.000000      7.000000
#
#        recently_promoted  satisfaction        tenure
# count              300.0  14068.000000  14068.000000
# mean                 1.0      0.621295      3.497228
# std                  0.0      0.250469      1.460917
# min                  1.0      0.040058      2.000000
# 25%                  1.0      0.450390      3.000000
# ...

# %%
main_df.department.value_counts()
# Out:
# sales                     3923
# engineering               2592
# support                   2122
# IT                        1161
# product                    860
# marketing                  819
# finance                    728
# management                 595
# information_technology     209
# temp                       181
# admin                      176
# procurement                174
# Name: department, dtype: int64

# %%
#тут текучість кадрів

# %% [markdown]
# # Cleaning

# %%
main_df.filed_complaint.fillna(0, inplace=True)
main_df.recently_promoted.fillna(0, inplace=True)
main_df.status.replace('Employed', 0, inplace=True)
main_df.status.replace('Left', 1, inplace=True)

# %%
display(main_df.salary.unique())
display(main_df.salary.value_counts())
# Out:
# array(['low', 'medium', 'high'], dtype=object)
# low       6952
# medium    6146
# high      1151
# Name: salary, dtype: int64

# %%
main_df.salary = main_df.salary.astype('category')
main_df.salary = main_df.salary.cat.reorder_categories(['low', 'medium', 'high'])
main_df.salary = main_df.salary.cat.codes

# %%
display(main_df.salary.value_counts())
# Out:
# 0    6952
# 1    6146
# 2    1151
# Name: salary, dtype: int64

# %%
main_df
# Out:
#        avg_monthly_hrs   department  filed_complaint  last_evaluation  \
# 0                  221  engineering              0.0         0.932868
# 1                  232      support              0.0              NaN
# 2                  184        sales              0.0         0.788830
# 3                  206        sales              0.0         0.575688
# 4                  249        sales              0.0         0.845217
# ...                ...          ...              ...              ...
# 14244              178           IT              0.0         0.735865
# 14245              257        sales              0.0         0.638604
# 14246              232      finance              1.0         0.847623
# 14247              130           IT              0.0         0.757184
# 14248              159          NaN              0.0         0.578742
#
#        n_projects  recently_promoted  salary  satisfaction  status  tenure
# ...

# %%
nan_tenure = main_df[main_df['tenure'].isnull() & main_df['last_evaluation'].isnull() & main_df['satisfaction'].isnull()]
nan_tenure
# Out:
#        avg_monthly_hrs department  filed_complaint  last_evaluation  \
# 24                 125       temp              0.0              NaN
# 28                  67       temp              0.0              NaN
# 44                  70       temp              0.0              NaN
# 252                 81       temp              0.0              NaN
# 291                 71       temp              0.0              NaN
# ...                ...        ...              ...              ...
# 13850               95       temp              0.0              NaN
# 14083              123       temp              0.0              NaN
# 14105               81       temp              1.0              NaN
# 14126              132       temp              0.0              NaN
# 14220              124       temp              0.0              NaN
#
#        n_projects  recently_promoted  salary  satisfaction  status  tenure
# 24              2                0.0       1           NaN       0     NaN
# ...

# %%
new_df = main_df[main_df['department'] != 'temp']
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14068 entries, 0 to 14248
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    14068 non-null  int64
#  1   department         13359 non-null  object
#  2   filed_complaint    14068 non-null  float64
#  3   last_evaluation    12717 non-null  float64
#  4   n_projects         14068 non-null  int64
#  5   recently_promoted  14068 non-null  float64
#  6   salary             14068 non-null  int8
#  7   satisfaction       14068 non-null  float64
#  8   status             14068 non-null  int64
#  9   tenure             14068 non-null  float64
# dtypes: float64(5), int64(3), int8(1), object(1)
# memory usage: 1.1+ MB

# %%
_ = plt.figure(figsize=(20, 10))
_ = sns.boxplot(x='department', y='last_evaluation', data=new_df)
_ = plt.ylabel('last_evaluation')
_ = plt.xlabel('department')
plt.show()

# %%
pivot_df = new_df.pivot_table(values=['last_evaluation', 'satisfaction', 'avg_monthly_hrs', 'tenure'], index='department', aggfunc=[np.mean, np.median]) 
pivot_df
# Out:
#                                   mean                                         \
#                        avg_monthly_hrs last_evaluation satisfaction    tenure
# department
# IT                          202.175711        0.720712     0.628324  3.481481
# admin                       201.272727        0.726282     0.611450  3.369318
# engineering                 202.469522        0.722332     0.617907  3.402392
# finance                     201.175824        0.723880     0.586787  3.543956
# information_technology      202.167464        0.716156     0.626717  3.315789
# management                  201.025210        0.729714     0.630428  4.294118
# marketing                   199.664225        0.715018     0.629122  3.567766
# procurement                 199.482759        0.699205     0.627930  3.264368
# product                     199.991860        0.719616     0.628774  3.487209
# sales                       200.842467        0.711254     0.623075  3.527148
# ...

# %%
nan_department = main_df[new_df['department'].isnull()]
nan_department
# Out:
#        avg_monthly_hrs department  filed_complaint  last_evaluation  \
# 39                 184        NaN              0.0         1.000000
# 64                 159        NaN              0.0         0.694101
# 87                 113        NaN              0.0         0.511794
# 100                241        NaN              0.0         0.766545
# 105                161        NaN              0.0         0.695098
# ...                ...        ...              ...              ...
# 14166              263        NaN              0.0         0.937390
# 14169              310        NaN              0.0         0.793898
# 14200              191        NaN              1.0         0.484292
# 14218              280        NaN              0.0         0.565752
# 14248              159        NaN              0.0         0.578742
#
#        n_projects  recently_promoted  salary  satisfaction  status  tenure
# 39              5                0.0       0      0.297124       0     5.0
# ...

# %%
nan_depart_eval = nan_department[nan_department['last_evaluation'].isnull()]
nan_depart_eval
# Out:
#        avg_monthly_hrs department  filed_complaint  last_evaluation  \
# 817                253        NaN              0.0              NaN
# 1074               258        NaN              0.0              NaN
# 1534               219        NaN              0.0              NaN
# 1553               131        NaN              1.0              NaN
# 1937               159        NaN              0.0              NaN
# ...                ...        ...              ...              ...
# 13058              193        NaN              0.0              NaN
# 13366              171        NaN              0.0              NaN
# 13427              143        NaN              0.0              NaN
# 13641              217        NaN              0.0              NaN
# 13861              149        NaN              0.0              NaN
#
#        n_projects  recently_promoted  salary  satisfaction  status  tenure
# 817             3                0.0       0      0.180917       0     3.0
# ...

# %%
main_df.department.fillna('Anonymous', inplace=True)
main_df
########################
# Out:
#        avg_monthly_hrs   department  filed_complaint  last_evaluation  \
# 0                  221  engineering              0.0         0.932868
# 1                  232      support              0.0              NaN
# 2                  184        sales              0.0         0.788830
# 3                  206        sales              0.0         0.575688
# 4                  249        sales              0.0         0.845217
# ...                ...          ...              ...              ...
# 14063              178           IT              0.0         0.735865
# 14064              257        sales              0.0         0.638604
# 14065              232      finance              1.0         0.847623
# 14066              130           IT              0.0         0.757184
# 14067              159    Anonymous              0.0         0.578742
#
#        n_projects  recently_promoted  salary  satisfaction  status  tenure
# ...

# %%
display(departm_clean_df.info())
display(departm_clean_df.describe())
display(departm_clean_df.status.value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14068 entries, 0 to 14248
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    14068 non-null  int64
#  1   department         13359 non-null  object
#  2   filed_complaint    14068 non-null  float64
#  3   last_evaluation    12717 non-null  float64
#  4   n_projects         14068 non-null  int64
#  5   recently_promoted  14068 non-null  float64
#  6   salary             14068 non-null  int8
#  7   satisfaction       14068 non-null  float64
#  8   status             14068 non-null  int64
#  9   tenure             14068 non-null  float64
# dtypes: float64(5), int64(3), int8(1), object(1)
# memory usage: 1.1+ MB
# None
#        avg_monthly_hrs  filed_complaint  last_evaluation    n_projects  \
# count     14068.000000     14068.000000     12717.000000  14068.000000
# ...

# %%
dummy_df = pd.get_dummies(departm_clean_df, drop_first=True)

# %%
del_departm = departm_clean_df.drop('department', axis=1)
corr_matrix = del_departm.corr()
plt.figure(figsize=(10, 7))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
corr_matrix = dummy_df.corr()
plt.figure(figsize=(20, 7))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
evaluation_df = dummy_df.dropna(subset='last_evaluation')

# %%
X = all_df.drop("status", axis=1)
y = all_df.status

# %%
steps = [('imputation', SimpleImputer()),
         ('knn', KNeighborsClassifier())]
pipeline = Pipeline(steps)

# %%
parameters = {'knn__n_neighbors': np.arange(1, 50)}
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state=42)
knn_cv = GridSearchCV(pipeline, param_grid=parameters, cv=5)

# %%
knn_cv.fit(X_train, y_train)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
_ = plt.figure(figsize=(20, 10))
_ = sns.boxplot(x='n_projects', y='last_evaluation', data=new_df)
_ = plt.ylabel('last_evaluation')
_ = plt.xlabel('n_project')
plt.show()

# %%
nan_ev = departm_clean_df[departm_clean_df['last_evaluation'].isnull()]
nan_ev.shape
# Out:
# (1284, 10)
