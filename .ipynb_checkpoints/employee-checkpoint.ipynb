# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.impute import SimpleImputer
sns.set()

# %%
main_df = pd.read_csv('data.csv')

# %%
main_df
# Out:
#        avg_monthly_hrs   department  filed_complaint  last_evaluation  \
# 0                  221  engineering              NaN         0.932868
# 1                  232      support              NaN              NaN
# 2                  184        sales              NaN         0.788830
# 3                  206        sales              NaN         0.575688
# 4                  249        sales              NaN         0.845217
# ...                ...          ...              ...              ...
# 14244              178           IT              NaN         0.735865
# 14245              257        sales              NaN         0.638604
# 14246              232      finance              1.0         0.847623
# 14247              130           IT              NaN         0.757184
# 14248              159          NaN              NaN         0.578742
#
#        n_projects  recently_promoted  salary  satisfaction    status  tenure
# ...

# %%
display(main_df.describe())
display(main_df.info())
# Out:
#        avg_monthly_hrs  filed_complaint  last_evaluation    n_projects  \
# count     14249.000000           2058.0     12717.000000  14249.000000
# mean        199.795775              1.0         0.718477      3.773809
# std          50.998714              0.0         0.173062      1.253126
# min          49.000000              1.0         0.316175      1.000000
# 25%         155.000000              1.0         0.563866      3.000000
# 50%         199.000000              1.0         0.724939      4.000000
# 75%         245.000000              1.0         0.871358      5.000000
# max         310.000000              1.0         1.000000      7.000000
#
#        recently_promoted  satisfaction        tenure
# count              300.0  14068.000000  14068.000000
# mean                 1.0      0.621295      3.497228
# std                  0.0      0.250469      1.460917
# min                  1.0      0.040058      2.000000
# 25%                  1.0      0.450390      3.000000
# ...

# %%
main_df.department.value_counts()
# Out:
# sales                     3923
# engineering               2592
# support                   2122
# IT                        1161
# product                    860
# marketing                  819
# finance                    728
# management                 595
# information_technology     209
# temp                       181
# admin                      176
# procurement                174
# Name: department, dtype: int64

# %%
main_df.filed_complaint.replace(np.nan, 0, inplace=True)
main_df.recently_promoted.replace(np.nan, 0, inplace=True)

# %%
nan_tenure = main_df[main_df['tenure'].isnull() & main_df['last_evaluation'].isnull() & main_df['satisfaction'].isnull()]
nan_tenure
# Out:
#        avg_monthly_hrs department  filed_complaint  last_evaluation  \
# 24                 125       temp              0.0              NaN
# 28                  67       temp              0.0              NaN
# 44                  70       temp              0.0              NaN
# 252                 81       temp              0.0              NaN
# 291                 71       temp              0.0              NaN
# ...                ...        ...              ...              ...
# 13850               95       temp              0.0              NaN
# 14083              123       temp              0.0              NaN
# 14105               81       temp              1.0              NaN
# 14126              132       temp              0.0              NaN
# 14220              124       temp              0.0              NaN
#
#        n_projects  recently_promoted  salary  satisfaction    status  tenure
# ...

# %%
new_df = main_df[main_df['department'] != 'temp']
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14068 entries, 0 to 14248
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    14068 non-null  int64
#  1   department         13359 non-null  object
#  2   filed_complaint    14068 non-null  float64
#  3   last_evaluation    12717 non-null  float64
#  4   n_projects         14068 non-null  int64
#  5   recently_promoted  14068 non-null  float64
#  6   salary             14068 non-null  object
#  7   satisfaction       14068 non-null  float64
#  8   status             14068 non-null  object
#  9   tenure             14068 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.2+ MB

# %%
_ = plt.figure(figsize=(20, 10))
_ = sns.boxplot(x='department', y='last_evaluation', data=new_df)
_ = plt.ylabel('last_evaluation')
_ = plt.xlabel('department')
plt.show()

# %%
mean_ev = new_df.groupby('department')['last_evaluation'].mean()
mean_ev
# Out:
# department
# IT                        0.720712
# admin                     0.726282
# engineering               0.722332
# finance                   0.723880
# information_technology    0.716156
# management                0.729714
# marketing                 0.715018
# procurement               0.699205
# product                   0.719616
# sales                     0.711254
# support                   0.723200
# Name: last_evaluation, dtype: float64

# %%
median_ev = new_df.groupby('department')['last_evaluation'].median()
median_ev
# Out:
# department
# IT                        0.727363
# admin                     0.740803
# engineering               0.732394
# finance                   0.735929
# information_technology    0.724781
# management                0.742450
# marketing                 0.713747
# procurement               0.696037
# product                   0.726919
# sales                     0.706577
# support                   0.735612
# Name: last_evaluation, dtype: float64

# %%
nan_department = new_df[new_df['department'].isnull()]
nan_department
# Out:
#        avg_monthly_hrs department  filed_complaint  last_evaluation  \
# 39                 184        NaN              0.0         1.000000
# 64                 159        NaN              0.0         0.694101
# 87                 113        NaN              0.0         0.511794
# 100                241        NaN              0.0         0.766545
# 105                161        NaN              0.0         0.695098
# ...                ...        ...              ...              ...
# 14166              263        NaN              0.0         0.937390
# 14169              310        NaN              0.0         0.793898
# 14200              191        NaN              1.0         0.484292
# 14218              280        NaN              0.0         0.565752
# 14248              159        NaN              0.0         0.578742
#
#        n_projects  recently_promoted  salary  satisfaction    status  tenure
# ...

# %%
nan_department.status.value_counts()
# Out:
# Employed    503
# Left        206
# Name: status, dtype: int64

# %%
employee_df = new_df.dropna(subset='department')
employee_df.status.value_counts()
# Out:
# Employed    10198
# Left         3161
# Name: status, dtype: int64

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13359 entries, 0 to 14247
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    13359 non-null  int64
#  1   department         13359 non-null  object
#  2   filed_complaint    13359 non-null  float64
#  3   last_evaluation    12075 non-null  float64
#  4   n_projects         13359 non-null  int64
#  5   recently_promoted  13359 non-null  float64
#  6   salary             13359 non-null  object
#  7   satisfaction       13359 non-null  float64
#  8   status             13359 non-null  object
#  9   tenure             13359 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.1+ MB

# %%
display(employee_df.salary.unique())
display(employee_df.salary.value_counts())
# Out:
# array(['low', 'medium', 'high'], dtype=object)
# low       6548
# medium    5713
# high      1098
# Name: salary, dtype: int64

# %%
employee_df.salary = employee_df.salary.astype('category')
employee_df.salary = employee_df.salary.cat.reorder_categories(['low', 'medium', 'high'])
employee_df.salary = employee_df.salary.cat.codes
# Out:
# C:\Users\IHOR\AppData\Local\Temp\ipykernel_9408\3529439310.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employee_df.salary = employee_df.salary.astype('category')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9408\3529439310.py in <module>
#       1 employee_df.salary = employee_df.salary.astype('category')
# ----> 2 employee_df.salary = employee_df.salary.cat.reorder_categories(['low', 'medium', 'high'])
#       3 employee_df.salary = employee_df.salary.cat.codes
#
# D:\Anaconda\lib\site-packages\pandas\core\accessor.py in f(self, *args, **kwargs)
# ...

# %%
display(employee_df.salary.value_counts())
# Out:
# 0    6548
# 1    5713
# 2    1098
# Name: salary, dtype: int64

# %%
employee_df.status.replace('Employed', 0, inplace=True)
# Out:
# C:\Users\IHOR\AppData\Local\Temp\ipykernel_9408\3338985889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employee_df.status.replace('Employed', 0, inplace=True)

# %%
corr_matrix = employee_df
sns.heatmap(corr_matrix)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9408\2365270254.py in <module>
#       1 corr_matrix = employee_df
# ----> 2 sns.heatmap(corr_matrix)
#       3 plt.show()
#
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\Anaconda\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     538     """
#     539     # Initialize the plotter object
# --> 540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...
